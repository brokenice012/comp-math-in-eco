# %% [markdown]
# # Week 1 assignment (test-assignment)
#
# "Hellow world" is a classic first program that one writes in every computer language :)

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Let's display Python version and the paratemers of the float point number representation on the current computer.

# %%
import sys
print('Python ' + sys.version)
print(sys.float_info)
# Out:
# Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
a = 159214
b = bin(a) # binary representation starting with '0b'
print(b)
# Out:
# 0b100110110111101110

# %% [markdown]
# A more elaborate example is below.
# See https://lectures.quantecon.org/py/python_by_example.html for full reference.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(100)
plt.plot(x)
plt.show()

# %% [markdown]
# **The assignment:**
# 1. Find the code from this notebook in _assingment1.py_ file
# 2. Run the code in Terminal by typing
# `python assignment1.py`
# 3. Modify the code in any way using a text editor
# 4. Commit the modified code to local repository
# 5. Push changes to GitHub
# 6. Create pull request (PR) to submit the assignment
